# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/FUSRP\ 2023/Deep\ Learning\ Models
# Out:
# /content/drive/MyDrive/FUSRP 2023/Deep Learning Models

# %%
while True:
  pass
